# %%
import boto3
import pandas as pd
import time
from datetime import datetime, timezone

# %%
# Load dataset
file_path = "test_task_data.csv"  
df = pd.read_csv(file_path)

df.head(3)
# Out:
#    customer_id   purchase_timestamp  purchase_value  loyalty_score
# 0           16   2022-01-02 7:43:18          211.40           9.17
# 1           62  2022-01-02 14:22:57          367.20           8.76
# 2           58   2022-01-05 2:33:56          237.01           1.41

# %%
# Convert purchase_timestamp to datetime format
df["purchase_timestamp"] = pd.to_datetime(df["purchase_timestamp"])

# Sort records in chronological order to simulate real-time streaming
df = df.sort_values(by="purchase_timestamp", ascending=True)

# Initialize SageMaker Feature Store client
sm_client = boto3.client("sagemaker-featurestore-runtime", region_name="us-east-2")

feature_group_name = "CustomerTransactions"

# Dictionary to store the latest record for each customer
latest_customer_records = {}

# %%
# Function to send records to Feature Store
def update_feature_store(row):
    customer_id = row["customer_id"]
    timestamp = row["purchase_timestamp"]
    
    # Format event_time in ISO 8601 format (required by SageMaker Feature Store)
    event_time = timestamp.replace(tzinfo=timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ")

    # Ensure only the latest record for each customer is updated
    latest_customer_records[customer_id] = {
        "FeatureGroupName": feature_group_name,
        "Record": [
            {"FeatureName": "customer_id", "ValueAsString": str(customer_id)},
            {"FeatureName": "event_time", "ValueAsString": event_time},
            {"FeatureName": "latest_purchase_value", "ValueAsString": str(row["purchase_value"])},
            {"FeatureName": "latest_loyalty_score", "ValueAsString": str(row["loyalty_score"])}
        ]
    }

    try:
        response = sm_client.put_record(**latest_customer_records[customer_id])
        print(f"✅ Successfully updated feature store for Customer ID: {customer_id}")
    except Exception as e:
        print(f"❌ Error updating feature store for Customer ID {customer_id}: {e}")

# Stream records one by one to simulate real-time updates
for _, row in df.iterrows():
    update_feature_store(row)
    time.sleep(1)  # Simulating delay for real-time data ingestion

print("🎯 Feature Store Update Completed!")
# Out:
# ✅ Successfully updated feature store for Customer ID: 16
# ✅ Successfully updated feature store for Customer ID: 62
# ✅ Successfully updated feature store for Customer ID: 58
# ✅ Successfully updated feature store for Customer ID: 7
# ✅ Successfully updated feature store for Customer ID: 26
# ✅ Successfully updated feature store for Customer ID: 50
# ✅ Successfully updated feature store for Customer ID: 98
# ✅ Successfully updated feature store for Customer ID: 44
# ✅ Successfully updated feature store for Customer ID: 83
# ✅ Successfully updated feature store for Customer ID: 81
# ✅ Successfully updated feature store for Customer ID: 24
# ✅ Successfully updated feature store for Customer ID: 64
# ✅ Successfully updated feature store for Customer ID: 60
# ✅ Successfully updated feature store for Customer ID: 19
# ✅ Successfully updated feature store for Customer ID: 84
# ✅ Successfully updated feature store for Customer ID: 94
# ✅ Successfully updated feature store for Customer ID: 70
# ✅ Successfully updated feature store for Customer ID: 47
# ✅ Successfully updated feature store for Customer ID: 32
# ✅ Successfully updated feature store for Customer ID: 100
# ✅ Successfully updated feature store for Customer ID: 55
# ✅ Successfully updated feature store for Customer ID: 29
# ✅ Successfully updated feature store for Customer ID: 7
# ✅ Successfully updated feature store for Customer ID: 57
# ✅ Successfully updated feature store for Customer ID: 41
# ✅ Successfully updated feature store for Customer ID: 24
# ✅ Successfully updated feature store for Customer ID: 43
# ✅ Successfully updated feature store for Customer ID: 71
# ✅ Successfully updated feature store for Customer ID: 65
# ✅ Successfully updated feature store for Customer ID: 85
# ✅ Successfully updated feature store for Customer ID: 69
# ✅ Successfully updated feature store for Customer ID: 70
# ✅ Successfully updated feature store for Customer ID: 47
# ✅ Successfully updated feature store for Customer ID: 12
# ✅ Successfully updated feature store for Customer ID: 35
# ✅ Successfully updated feature store for Customer ID: 35
# ✅ Successfully updated feature store for Customer ID: 76
# ✅ Successfully updated feature store for Customer ID: 54
# ✅ Successfully updated feature store for Customer ID: 20
# ✅ Successfully updated feature store for Customer ID: 99
# ✅ Successfully updated feature store for Customer ID: 65
# ✅ Successfully updated feature store for Customer ID: 96
# ✅ Successfully updated feature store for Customer ID: 35
# ✅ Successfully updated feature store for Customer ID: 89
# ✅ Successfully updated feature store for Customer ID: 12
# ✅ Successfully updated feature store for Customer ID: 69
# ✅ Successfully updated feature store for Customer ID: 6
# ✅ Successfully updated feature store for Customer ID: 13
# ✅ Successfully updated feature store for Customer ID: 56
# ✅ Successfully updated feature store for Customer ID: 72
# ✅ Successfully updated feature store for Customer ID: 50
# ✅ Successfully updated feature store for Customer ID: 26
# ✅ Successfully updated feature store for Customer ID: 90
# ✅ Successfully updated feature store for Customer ID: 100
# ✅ Successfully updated feature store for Customer ID: 19
# ✅ Successfully updated feature store for Customer ID: 68
# ✅ Successfully updated feature store for Customer ID: 1
# ✅ Successfully updated feature store for Customer ID: 95
# ✅ Successfully updated feature store for Customer ID: 5
# ✅ Successfully updated feature store for Customer ID: 12
# ✅ Successfully updated feature store for Customer ID: 63
# ✅ Successfully updated feature store for Customer ID: 36
# ✅ Successfully updated feature store for Customer ID: 62
# ✅ Successfully updated feature store for Customer ID: 18
# ✅ Successfully updated feature store for Customer ID: 67
# ✅ Successfully updated feature store for Customer ID: 9
# ✅ Successfully updated feature store for Customer ID: 69
# ✅ Successfully updated feature store for Customer ID: 17
# ✅ Successfully updated feature store for Customer ID: 1
# ✅ Successfully updated feature store for Customer ID: 84
# ✅ Successfully updated feature store for Customer ID: 62
# ✅ Successfully updated feature store for Customer ID: 64
# ✅ Successfully updated feature store for Customer ID: 51
# ✅ Successfully updated feature store for Customer ID: 56
# ✅ Successfully updated feature store for Customer ID: 52
# ✅ Successfully updated feature store for Customer ID: 65
# ✅ Successfully updated feature store for Customer ID: 42
# ✅ Successfully updated feature store for Customer ID: 63
# ✅ Successfully updated feature store for Customer ID: 42
# ✅ Successfully updated feature store for Customer ID: 39
# ✅ Successfully updated feature store for Customer ID: 3
# ✅ Successfully updated feature store for Customer ID: 62
# ✅ Successfully updated feature store for Customer ID: 4
# ✅ Successfully updated feature store for Customer ID: 1
# ✅ Successfully updated feature store for Customer ID: 16
# ✅ Successfully updated feature store for Customer ID: 76
# ✅ Successfully updated feature store for Customer ID: 24
# ✅ Successfully updated feature store for Customer ID: 3
# ✅ Successfully updated feature store for Customer ID: 25
# ✅ Successfully updated feature store for Customer ID: 43
# ✅ Successfully updated feature store for Customer ID: 39
# ✅ Successfully updated feature store for Customer ID: 17
# ✅ Successfully updated feature store for Customer ID: 65
# ✅ Successfully updated feature store for Customer ID: 75
# ✅ Successfully updated feature store for Customer ID: 64
# ✅ Successfully updated feature store for Customer ID: 93
# ✅ Successfully updated feature store for Customer ID: 81
# ✅ Successfully updated feature store for Customer ID: 56
# ✅ Successfully updated feature store for Customer ID: 58
# ✅ Successfully updated feature store for Customer ID: 7
# ✅ Successfully updated feature store for Customer ID: 78
# ✅ Successfully updated feature store for Customer ID: 46
# ✅ Successfully updated feature store for Customer ID: 43
# ✅ Successfully updated feature store for Customer ID: 50
# ✅ Successfully updated feature store for Customer ID: 86
# ✅ Successfully updated feature store for Customer ID: 23
# ✅ Successfully updated feature store for Customer ID: 11
# ✅ Successfully updated feature store for Customer ID: 20
# ✅ Successfully updated feature store for Customer ID: 66
# ✅ Successfully updated feature store for Customer ID: 90
# ✅ Successfully updated feature store for Customer ID: 45
# ✅ Successfully updated feature store for Customer ID: 13
# ✅ Successfully updated feature store for Customer ID: 76
# ✅ Successfully updated feature store for Customer ID: 44
# ✅ Successfully updated feature store for Customer ID: 8
# ✅ Successfully updated feature store for Customer ID: 45
# ✅ Successfully updated feature store for Customer ID: 75
# ✅ Successfully updated feature store for Customer ID: 3
# ✅ Successfully updated feature store for Customer ID: 88
# ✅ Successfully updated feature store for Customer ID: 73
# ✅ Successfully updated feature store for Customer ID: 14
# ✅ Successfully updated feature store for Customer ID: 84
# ✅ Successfully updated feature store for Customer ID: 31
# ✅ Successfully updated feature store for Customer ID: 42
# ✅ Successfully updated feature store for Customer ID: 75
# ✅ Successfully updated feature store for Customer ID: 81
# ✅ Successfully updated feature store for Customer ID: 94
# ✅ Successfully updated feature store for Customer ID: 22
# ✅ Successfully updated feature store for Customer ID: 53
# ✅ Successfully updated feature store for Customer ID: 68
# ✅ Successfully updated feature store for Customer ID: 33
# ✅ Successfully updated feature store for Customer ID: 79
# ✅ Successfully updated feature store for Customer ID: 16
# ✅ Successfully updated feature store for Customer ID: 24
# ✅ Successfully updated feature store for Customer ID: 5
# ✅ Successfully updated feature store for Customer ID: 30
# ✅ Successfully updated feature store for Customer ID: 10
# ✅ Successfully updated feature store for Customer ID: 25
# ✅ Successfully updated feature store for Customer ID: 25
# ✅ Successfully updated feature store for Customer ID: 96
# ✅ Successfully updated feature store for Customer ID: 20
# ✅ Successfully updated feature store for Customer ID: 81
# ✅ Successfully updated feature store for Customer ID: 71
# ✅ Successfully updated feature store for Customer ID: 28
# ✅ Successfully updated feature store for Customer ID: 43
# ✅ Successfully updated feature store for Customer ID: 12
# ✅ Successfully updated feature store for Customer ID: 31
# ✅ Successfully updated feature store for Customer ID: 9
# ✅ Successfully updated feature store for Customer ID: 25
# ✅ Successfully updated feature store for Customer ID: 85
# ✅ Successfully updated feature store for Customer ID: 73
# ✅ Successfully updated feature store for Customer ID: 48
# ✅ Successfully updated feature store for Customer ID: 63
# ✅ Successfully updated feature store for Customer ID: 91
# ✅ Successfully updated feature store for Customer ID: 20
# ✅ Successfully updated feature store for Customer ID: 88
# ✅ Successfully updated feature store for Customer ID: 27
# ✅ Successfully updated feature store for Customer ID: 44
# ✅ Successfully updated feature store for Customer ID: 85
# ✅ Successfully updated feature store for Customer ID: 92
# ✅ Successfully updated feature store for Customer ID: 94
# ✅ Successfully updated feature store for Customer ID: 85
# ✅ Successfully updated feature store for Customer ID: 14
# ✅ Successfully updated feature store for Customer ID: 4
# ✅ Successfully updated feature store for Customer ID: 100
# ✅ Successfully updated feature store for Customer ID: 15
# ✅ Successfully updated feature store for Customer ID: 64
# ✅ Successfully updated feature store for Customer ID: 96
# ✅ Successfully updated feature store for Customer ID: 56
# ✅ Successfully updated feature store for Customer ID: 29
# ✅ Successfully updated feature store for Customer ID: 76
# ✅ Successfully updated feature store for Customer ID: 23
# ✅ Successfully updated feature store for Customer ID: 6
# ✅ Successfully updated feature store for Customer ID: 61
# ✅ Successfully updated feature store for Customer ID: 66
# ✅ Successfully updated feature store for Customer ID: 90
# ✅ Successfully updated feature store for Customer ID: 45
# ✅ Successfully updated feature store for Customer ID: 60
# ✅ Successfully updated feature store for Customer ID: 86
# ✅ Successfully updated feature store for Customer ID: 74
# ✅ Successfully updated feature store for Customer ID: 80
# ✅ Successfully updated feature store for Customer ID: 96
# ✅ Successfully updated feature store for Customer ID: 98
# ❌ Error updating feature store for Customer ID 50: An error occurred (ValidationError) when calling the PutRecord operation: Validation Error: Provided values for Feature(s) [latest_loyalty_score] which do not exist in FeatureGroup [CustomerTransactions].
# ✅ Successfully updated feature store for Customer ID: 13
# ✅ Successfully updated feature store for Customer ID: 17
# ✅ Successfully updated feature store for Customer ID: 87
# ✅ Successfully updated feature store for Customer ID: 77
# ✅ Successfully updated feature store for Customer ID: 34
# ✅ Successfully updated feature store for Customer ID: 16
# ✅ Successfully updated feature store for Customer ID: 99
# ✅ Successfully updated feature store for Customer ID: 12
# ✅ Successfully updated feature store for Customer ID: 26
# ✅ Successfully updated feature store for Customer ID: 2
# ✅ Successfully updated feature store for Customer ID: 87
# ✅ Successfully updated feature store for Customer ID: 10
# ✅ Successfully updated feature store for Customer ID: 45
# ✅ Successfully updated feature store for Customer ID: 13
# ✅ Successfully updated feature store for Customer ID: 93
# ✅ Successfully updated feature store for Customer ID: 42
# ✅ Successfully updated feature store for Customer ID: 40
# ✅ Successfully updated feature store for Customer ID: 41
# ✅ Successfully updated feature store for Customer ID: 27
# ✅ Successfully updated feature store for Customer ID: 82
# ✅ Successfully updated feature store for Customer ID: 99
# ✅ Successfully updated feature store for Customer ID: 50
# ✅ Successfully updated feature store for Customer ID: 57
# ✅ Successfully updated feature store for Customer ID: 95
# ✅ Successfully updated feature store for Customer ID: 52
# ✅ Successfully updated feature store for Customer ID: 79
# ✅ Successfully updated feature store for Customer ID: 71
# ✅ Successfully updated feature store for Customer ID: 49
# ✅ Successfully updated feature store for Customer ID: 16
# ✅ Successfully updated feature store for Customer ID: 25
# ✅ Successfully updated feature store for Customer ID: 92
# ✅ Successfully updated feature store for Customer ID: 91
# ✅ Successfully updated feature store for Customer ID: 86
# ✅ Successfully updated feature store for Customer ID: 17
# ✅ Successfully updated feature store for Customer ID: 62
# ✅ Successfully updated feature store for Customer ID: 1
# ✅ Successfully updated feature store for Customer ID: 42
# ✅ Successfully updated feature store for Customer ID: 68
# ✅ Successfully updated feature store for Customer ID: 100
# ✅ Successfully updated feature store for Customer ID: 61
# ✅ Successfully updated feature store for Customer ID: 10
# ✅ Successfully updated feature store for Customer ID: 99
# ✅ Successfully updated feature store for Customer ID: 87
# ✅ Successfully updated feature store for Customer ID: 76
# ✅ Successfully updated feature store for Customer ID: 19
# ✅ Successfully updated feature store for Customer ID: 47
# ✅ Successfully updated feature store for Customer ID: 90
# ✅ Successfully updated feature store for Customer ID: 43
# ✅ Successfully updated feature store for Customer ID: 9
# ✅ Successfully updated feature store for Customer ID: 41
# ✅ Successfully updated feature store for Customer ID: 4
# ✅ Successfully updated feature store for Customer ID: 56
# ✅ Successfully updated feature store for Customer ID: 58
# ✅ Successfully updated feature store for Customer ID: 74
# ✅ Successfully updated feature store for Customer ID: 51
# ✅ Successfully updated feature store for Customer ID: 5
# ✅ Successfully updated feature store for Customer ID: 92
# ✅ Successfully updated feature store for Customer ID: 28
# ✅ Successfully updated feature store for Customer ID: 19
# ✅ Successfully updated feature store for Customer ID: 95
# ✅ Successfully updated feature store for Customer ID: 35
# ✅ Successfully updated feature store for Customer ID: 97
# ✅ Successfully updated feature store for Customer ID: 28
# ✅ Successfully updated feature store for Customer ID: 32
# ✅ Successfully updated feature store for Customer ID: 41
# ✅ Successfully updated feature store for Customer ID: 99
# ✅ Successfully updated feature store for Customer ID: 29
# ✅ Successfully updated feature store for Customer ID: 93
# ✅ Successfully updated feature store for Customer ID: 70
# ✅ Successfully updated feature store for Customer ID: 22
# ✅ Successfully updated feature store for Customer ID: 26
# ✅ Successfully updated feature store for Customer ID: 10
# ✅ Successfully updated feature store for Customer ID: 15
# ✅ Successfully updated feature store for Customer ID: 75
# ✅ Successfully updated feature store for Customer ID: 51
# ✅ Successfully updated feature store for Customer ID: 88
# ✅ Successfully updated feature store for Customer ID: 59
# ✅ Successfully updated feature store for Customer ID: 79
# ✅ Successfully updated feature store for Customer ID: 83
# ✅ Successfully updated feature store for Customer ID: 63
# ✅ Successfully updated feature store for Customer ID: 40
# ✅ Successfully updated feature store for Customer ID: 60
# ✅ Successfully updated feature store for Customer ID: 73
# ✅ Successfully updated feature store for Customer ID: 87
# ✅ Successfully updated feature store for Customer ID: 66
# ✅ Successfully updated feature store for Customer ID: 64
# ✅ Successfully updated feature store for Customer ID: 86
# ✅ Successfully updated feature store for Customer ID: 38
# ✅ Successfully updated feature store for Customer ID: 31
# ✅ Successfully updated feature store for Customer ID: 69
# ✅ Successfully updated feature store for Customer ID: 55
# ✅ Successfully updated feature store for Customer ID: 58
# ✅ Successfully updated feature store for Customer ID: 21
# ✅ Successfully updated feature store for Customer ID: 29
# ✅ Successfully updated feature store for Customer ID: 9
# ✅ Successfully updated feature store for Customer ID: 71
# ✅ Successfully updated feature store for Customer ID: 86
# ✅ Successfully updated feature store for Customer ID: 60
# ✅ Successfully updated feature store for Customer ID: 87
# ✅ Successfully updated feature store for Customer ID: 28
# ✅ Successfully updated feature store for Customer ID: 85
# ✅ Successfully updated feature store for Customer ID: 74
# ✅ Successfully updated feature store for Customer ID: 71
# ✅ Successfully updated feature store for Customer ID: 53
# ✅ Successfully updated feature store for Customer ID: 60
# ✅ Successfully updated feature store for Customer ID: 37
# ✅ Successfully updated feature store for Customer ID: 15
# ✅ Successfully updated feature store for Customer ID: 95
# ✅ Successfully updated feature store for Customer ID: 54
# ✅ Successfully updated feature store for Customer ID: 5
# ✅ Successfully updated feature store for Customer ID: 14
# ✅ Successfully updated feature store for Customer ID: 82
# ✅ Successfully updated feature store for Customer ID: 90
# ✅ Successfully updated feature store for Customer ID: 18
# ✅ Successfully updated feature store for Customer ID: 31
# ✅ Successfully updated feature store for Customer ID: 55
# ✅ Successfully updated feature store for Customer ID: 47
# ✅ Successfully updated feature store for Customer ID: 13
# ✅ Successfully updated feature store for Customer ID: 14
# ✅ Successfully updated feature store for Customer ID: 97
# ✅ Successfully updated feature store for Customer ID: 4
# 🎯 Feature Store Update Completed!

# %%
#Function to fetch the latest features given a customer_id

def get_latest_features(customer_id):
    response = sm_client.get_record(
        FeatureGroupName=feature_group_name,
        RecordIdentifierValueAsString=str(customer_id)
    )
    
    features = {feature['FeatureName']: feature['ValueAsString'] for feature in response.get('Record', [])}
    
    return features

# Example: Fetch latest features
customer_id = 29
latest_features = get_latest_features(customer_id)

latest_purchase_value = float(latest_features.get("latest_purchase_value", 0.0))
latest_loyalty_score = float(latest_features.get("latest_loyalty_score", 0.0))

print(f"Latest Purchase Value: {latest_purchase_value}")
print(f"Latest Loyalty Score: {latest_loyalty_score}")
# Out:
# Latest Purchase Value: 177.47
# Latest Loyalty Score: 6.7
